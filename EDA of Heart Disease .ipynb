# %% [markdown]
# #  Import the libraries and datasets

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\91960\OneDrive\Desktop\Project\PYTHON\Heart disease EDA\archive\heart.csv')
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# # Display top 5 rows of the dataset

# %%
data.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# # Check last 5 rows of the dataset

# %%
data.tail(5)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %% [markdown]
# # Find shape of our dataset

# %%
data.shape
# Out:
# (1025, 14)

# %% [markdown]
# # Get info about our dataset like total number of rows and columns, datatypes of each column and memory

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# # Check null values in the dataset

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# # Check for duplicate data and drop them

# %%
data.duplicated().any()
# Out:
# True

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (302, 14)

# %% [markdown]
# # Get overall statistics about the dataset

# %%
data.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %% [markdown]
# # Draw correlation matrix

# %%
plt.figure(figsize=(17,6))
sns.heatmap(data.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # How many people have Heart disease, and how many don't have Heart disease in the dataset

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['target'].value_counts()
# Out:
# 1    164
# 0    138
# Name: target, dtype: int64

# %%
sns.countplot(x = data['target'],data = data)
plt.show()

# %% [markdown]
# # Find count of Male and Female in the dataset

# %%
sns.countplot(y = data['sex'], data = data, palette = 'Set2')
plt.yticks([0,1],['Female','Male'])
# Out:
# ([<matplotlib.axis.YTick at 0x2909e48dd50>,
# ...
#  [Text(0, 0, 'Female'), Text(0, 1, 'Male')])

# %% [markdown]
# # Find gender distribution according to the Target variable

# %%
sns.countplot(x = 'sex', hue = 'target', data = data)
plt.xticks([1,0],['Male','Female'])
plt.legend(labels = ['No disease','Disease'])
plt.show()

# %% [markdown]
# # Check age distribution in the dataset

# %%
sns.histplot(data['age'], bins = 20)
plt.show()


sns.histplot(data)

# %% [markdown]
# # Check Chest Pain Type

# %% [markdown]
# Chest pain type (4 values)
# - value 0: typical angina
# - value 1: atypical angina
# - value 2: non-anginal pain
# - value 3: asymptomatic

# %%
sns.countplot(y = data['cp'],data = data)
plt.yticks([0,1,2,3],['Typical Angina','Atypical Angina','Non-Anginal','Asymptomatic'])
plt.ylabel('Chest pain')
plt.show()

# %% [markdown]
# # Show the chest pain distribution as per target variable

# %%
sns.countplot(x = data['cp'], hue='target', data = data)
plt.legend(labels = ['No Disease','Disease'])
plt.show()

# %% [markdown]
# # Show fasting blood sugar distribution according to target variable

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.countplot(y = data['fbs'], hue='target', data = data)
plt.show()

# %% [markdown]
# # Check resting blood pressure distribution

# %%
data['trestbps'].hist()
plt.show()

# %% [markdown]
# # Compare resing blood pressure as per sex column

# %%
g = sns.FacetGrid(data, hue='sex', aspect = 4)
g.map(sns.kdeplot,'trestbps', fill = True)
plt.legend(labels = ['Male','Female'])
plt.show()
# Out:
# C:\Users\91960\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Show Distribution of Serum Cholesterol

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['chol'].hist()
plt.show()

# %% [markdown]
# # Plot Continuous Variables

# %%
category_variable = []
continuous_variable = []

for column in data.columns:
    if data[column].nunique() <= 10:
        category_variable.append(column)
    else:
        continuous_variable.append(column)

# %%
category_variable
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']

# %%
continuous_variable
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
data.hist(continuous_variable, figsize = (20,20))
plt.tight_layout()
plt.show()
